# %%
import pandas as pd

# %%
import os

# %%
file_path='D:\\1_kaoyan\\college_ending\\400仪表数据--全\\middata - 副本\\分时线损数据——按照指标来算'

# %%
name_box=[]
for i,j,k in os.walk(file_path):
    
    print(i)
    print(j)
    print(k)
    name_box.append(k)
# Out:
# D:\1_kaoyan\college_ending\400仪表数据--全\middata - 副本\分时线损数据——按照指标来算
# []
# ['2——FourHundred_lp-line-loss_CollectedQty.txt.csv', 'all——分时线损数据.xlsx', 'FourHundred_lp-line-loss_CollectedQty.txt', 'FourHundred_lp-line-loss_Consumed.txt', 'FourHundred_lp-line-loss_Estimated.txt', 'FourHundred_lp-line-loss_ExportA.txt', 'FourHundred_lp-line-loss_ExportEsA.txt', 'FourHundred_lp-line-loss_ExportEsR.txt', 'FourHundred_lp-line-loss_ExportR.txt', 'FourHundred_lp-line-loss_GmExportA.txt', 'FourHundred_lp-line-loss_GmExportR.txt', 'FourHundred_lp-line-loss_GmImportA.txt', 'FourHundred_lp-line-loss_GmImportR.txt', 'FourHundred_lp-line-loss_GmQty.txt', 'FourHundred_lp-line-loss_ImportA.txt', 'FourHundred_lp-line-loss_ImportEsA.txt', 'FourHundred_lp-line-loss_ImportEsR.txt', 'FourHundred_lp-line-loss_LossRatio.txt', 'FourHundred_lp-line-loss_LossUsage.txt', 'FourHundred_lp-line-loss_MaxCurrent.txt', 'FourHundred_lp-line-loss_MeterQty.txt', 'FourHundred_lp-line-loss_Supplied.txt', 'FourHundred_lp-line-loss_TechLossRatio.txt', 'FourHundred_lp-line-loss_TechLossUsage.txt']

# %%
k
# Out:
# ['2——FourHundred_lp-line-loss_CollectedQty.txt.csv',
#  'all——分时线损数据.xlsx',
#  'FourHundred_lp-line-loss_CollectedQty.txt',
#  'FourHundred_lp-line-loss_Consumed.txt',
#  'FourHundred_lp-line-loss_Estimated.txt',
#  'FourHundred_lp-line-loss_ExportA.txt',
#  'FourHundred_lp-line-loss_ExportEsA.txt',
#  'FourHundred_lp-line-loss_ExportEsR.txt',
#  'FourHundred_lp-line-loss_ExportR.txt',
#  'FourHundred_lp-line-loss_GmExportA.txt',
#  'FourHundred_lp-line-loss_GmExportR.txt',
#  'FourHundred_lp-line-loss_GmImportA.txt',
#  'FourHundred_lp-line-loss_GmImportR.txt',
#  'FourHundred_lp-line-loss_GmQty.txt',
#  'FourHundred_lp-line-loss_ImportA.txt',
#  'FourHundred_lp-line-loss_ImportEsA.txt',
#  'FourHundred_lp-line-loss_ImportEsR.txt',
#  'FourHundred_lp-line-loss_LossRatio.txt',
#  'FourHundred_lp-line-loss_LossUsage.txt',
#  'FourHundred_lp-line-loss_MaxCurrent.txt',
#  'FourHundred_lp-line-loss_MeterQty.txt',
#  'FourHundred_lp-line-loss_Supplied.txt',
#  'FourHundred_lp-line-loss_TechLossRatio.txt',
#  'FourHundred_lp-line-loss_TechLossUsage.txt']

# %%
for name in k[2:]:
    file_name=file_path+name
    file_name.replace(r'\', r'\\')
    print(file_name)
# Out:
#   File "<ipython-input-18-45c5259d4dac>", line 3
#     file_name.replace(r'\', r'\\')
#                                   ^
# SyntaxError: unexpected character after line continuation character

# %%
inputfile="D:\\1_kaoyan\college_ending\\400仪表数据--全\\middata - 副本\\分时线损数据——按照指标来算\\FourHundred_lp-line-loss_CollectedQty.txt"

# %%
data = pd.read_csv(inputfile,sep='\t',encoding='utf-8')

# %%
data.head(5)
# Out:
#    Unnamed: 0    regionId  M20200101000000  M20200101003000  M20200101010000  \
# 0  1180000258  1180000258            106.0            107.0            107.0
# 1  1180000259  1180000259             13.0             13.0             13.0
# 2  1180000260  1180000260            122.0            122.0            122.0
# 3  1180000261  1180000261             12.0             12.0             12.0
# 4  1180000263  1180000263            129.0            130.0            131.0
#
#    M20200101013000  M20200101020000  M20200101023000  M20200101030000  \
# 0            107.0            107.0            107.0            107.0
# 1             13.0             13.0             13.0             13.0
# 2            122.0            122.0            122.0            122.0
# 3             12.0             12.0             12.0             12.0
# 4            131.0            131.0            131.0            131.0
#
#    M20200101033000  ...  M20201231190000  M20201231193000  M20201231200000  \
# 0            108.0  ...              137              137              137
# 1             13.0  ...               16               16               16
# 2            122.0  ...              141              141              141
# 3             12.0  ...               19               19               19
# 4            131.0  ...              127              127              127
#
#    M20201231203000  M20201231210000  M20201231213000  M20201231220000  \
# 0              137              137              137              137
# 1               16               17               17               17
# 2              141              141              141              141
# 3               19               19               19               19
# 4              127              127              127              127
#
#    M20201231223000  M20201231230000  M20201231233000
# 0              137              136              136
# 1               17               17               17
# 2              141              141              141
# 3               19               19               19
# 4              127              127              127
#
# [5 rows x 16768 columns]

# %%
data['regionId']=data['regionId'].astype('object')

# %%
data_change=data.T

# %%
data_change.head(5)
# Out:
#                         0           1           2           3           4    \
# Unnamed: 0       1180000258  1180000259  1180000260  1180000261  1180000263
# regionId         1180000258  1180000259  1180000260  1180000261  1180000263
# M20200101000000       106.0        13.0       122.0        12.0       129.0
# M20200101003000       107.0        13.0       122.0        12.0       130.0
# M20200101010000       107.0        13.0       122.0        12.0       131.0
#
#                         5           6           7           8           9    \
# Unnamed: 0       1180000268  1180000270  1180000272  1180000274  1180000280
# regionId         1180000268  1180000270  1180000272  1180000274  1180000280
# M20200101000000        65.0        71.0        78.0        34.0        26.0
# M20200101003000        66.0        72.0        80.0        34.0        29.0
# M20200101010000        67.0        72.0        79.0        34.0        29.0
#
#                  ...         111         112         113         114  \
# Unnamed: 0       ...  1180000236  1180029933  1180000239  1180000240
# regionId         ...  1180000236  1180029933  1180000239  1180000240
# M20200101000000  ...       109.0         NaN       138.0       114.0
# M20200101003000  ...       109.0         NaN       138.0       115.0
# M20200101010000  ...       109.0         NaN       138.0       115.0
#
#                         115         116         117         118         119  \
# Unnamed: 0       1180000243  1180000244  1180000247  1180000248  1180000249
# regionId         1180000243  1180000244  1180000247  1180000248  1180000249
# M20200101000000       143.0         2.0        72.0         6.0         3.0
# M20200101003000       143.0         2.0        75.0         6.0         3.0
# M20200101010000       143.0         2.0        75.0         6.0         3.0
#
#                         120
# Unnamed: 0       1180000254
# regionId         1180000254
# M20200101000000         1.0
# M20200101003000         1.0
# M20200101010000         1.0
#
# [5 rows x 121 columns]

# %%
inputfile.replace('.txt', '1.txt')
# Out:
# 'D:\\1_kaoyan\\college_ending\\400仪表数据--全\\middata - 副本\\分时线损数据——按照指标来算\\FourHundred_lp-line-loss_CollectedQty1.txt'

# %%
data_change.to_csv('inputfile.csv')
