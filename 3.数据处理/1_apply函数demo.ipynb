# %%
import pandas as pd
import numpy as np

# %%
boolean=[True,False]
gender=["男","女"]
color=["white","black","yellow"]
data=pd.DataFrame({
    "height":np.random.randint(150,190,100),
    "weight":np.random.randint(40,90,100),
    "smoker":[boolean[x] for x in np.random.randint(0,2,100)],
    "gender":[gender[x] for x in np.random.randint(0,2,100)],
    "age":np.random.randint(15,90,100),
    "color":[color[x] for x in np.random.randint(0,len(color),100) ]
}
)

# %%
data
# Out:
#     height  weight  smoker gender  age   color        BMI
# 0      166      70   False      男   23   black  25.402816
# 1      163      48    True      女   34   white  18.066167
# 2      164      87   False      女   33   black  32.346817
# 3      159      79    True      女   36  yellow  31.248764
# 4      177      89   False      男   19   white  28.408184
# ..     ...     ...     ...    ...  ...     ...        ...
# 95     173      87   False      女   30   white  29.068796
# 96     173      45   False      男   27   white  15.035584
# 97     154      62   False      男   31   black  26.142688
# 98     150      53   False      女   52   black  23.555556
# 99     187      53    True      女   70   black  15.156281
#
# [100 rows x 7 columns]

# %%
def BMI(series):
    weight = series["weight"]
    height = series["height"]/100
    BMI = weight/height**2
    return BMI

data["BMI"] = data.apply(BMI,axis=1)
